# %%
import pandas as pd
import requests
import numpy as np

# !pip install geopy
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
from geopy.distance import great_circle

# !pip install folium
import folium # map rendering library

import json # library to handle JSON files

import requests # library to handle requests
from requests import get

from bs4 import BeautifulSoup

import re

from time import sleep

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

import seaborn as sns

import json # library to handle JSON files
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# import k-means from clustering stage
from sklearn.cluster import KMeans

# %%
from bs4 import BeautifulSoup
url = 'https://en.wikipedia.org/wiki/List_of_neighbourhoods_in_Mumbai'
website_url = requests.get(url).text

soup = BeautifulSoup(website_url,'html.parser')
# print(soup.prettify())
table=soup.find('table')
table
res = []
for tr in table.find_all('tr'):
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td if tr.text.strip()]
    if row:
        res.append(row)
res

Mumbai_neighborhood = pd.DataFrame(res, columns=["Area", "Location", "Latitude", "Longitude"])
Mumbai_neighborhood
# Out:
#                 Area                 Location   Latitude  Longitude
# 0             Amboli  Andheri,Western Suburbs    19.1293    72.8434
# 1   Chakala, Andheri          Western Suburbs  19.111388  72.860833
# 2         D.N. Nagar  Andheri,Western Suburbs  19.124085  72.831373
# 3     Four Bungalows  Andheri,Western Suburbs  19.124714   72.82721
# 4        Lokhandwala  Andheri,Western Suburbs  19.130815   72.82927
# ..               ...                      ...        ...        ...
# 88             Parel             South Mumbai      18.99      72.84
# 89      Gowalia Tank      Tardeo,South Mumbai   18.96245  72.809703
# 90       Dava Bazaar             South Mumbai  18.946882  72.831362
# 91           Dharavi                   Mumbai  19.040208   72.85085
# 92             Thane                   Mumbai       19.2      72.97
#
# [93 rows x 4 columns]

# %%
address = 'Mumbai, India'

geolocator = Nominatim(user_agent="india_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Mumbai, India are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Mumbai, India are 19.0759899, 72.8773928.

# %%
map_mumbai = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, area, location in zip(Mumbai_neighborhood['Latitude'], Mumbai_neighborhood['Longitude'], Mumbai_neighborhood['Area'], Mumbai_neighborhood['Location']):
    label = '{}, {}'.format(location, area)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_mumbai)  
    
map_mumbai
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
url='https://memumbai.com/ward-wise-breakdown-of-covid-19-positive-cases/'

covid_data = pd.read_html(url)
temp_df = covid_data[0]
temp_df.drop([0],axis=0,inplace=True)
temp_df.rename(columns={0:"Ward",1:"Discharged",2:"Deaths",3:"Active",4:"Total Patients"},inplace=True)
temp_df = temp_df.astype({'Ward':str,'Discharged':str,'Deaths':str,'Active':str,'Total Patients':str})
covid_data_df = pd.DataFrame({'Ward':temp_df.loc[1]['Ward'].split(' '),'Discharged':temp_df.loc[1]['Discharged'].split(' '),'Deaths':temp_df.loc[1]['Deaths'].split(' '),'Active':temp_df.loc[1]['Active'].split(' '),'Total Patients':temp_df.loc[1]['Total Patients'].split(' ')})
covid_data_df = covid_data_df.astype({'Ward':str,'Discharged':int,'Deaths':int,'Active':int,'Total Patients':int})
covid_data_df
# Out:
#    Ward  Discharged  Deaths  Active  Total Patients
# 0    KW       22848     585    3424           26923
# 1    RC       23368     665    2300           26376
# 2    KE       19443     858    2592           22967
# 3    RS       20087     580    2061           22789
# 4    PN       19626     669    1959           22320
# 5     T       17849     383    2240           20513
# 6     N       16429     610    2120           19222
# 7     S       16159     727    1798           18723
# 8    GN       14904     683    1522           17185
# 9     D       15064     448    1587           17130
# 10   PS       13360     413    2002           15812
# 11   FN       12969     451    1694           15174
# 12    L       12322     572    1560           14497
# 13   HW       12284     330    1798           14438
# 14   FS       11285     516     835           12677
# 15   HE       10668     501    1470           12670
# 16   GS       11009     558    1015           12622
# ...

# %%
mumbai_ward_details = pd.read_csv('Mumbai_ward_details.csv')
mumbai_ward_details
# Out:
#    Ward                              Areas under this Ward
# 0     A                 Churchgate, Colaba, and Navy Nagar
# 1     B  Masjid Bunder, Mohd. Ali Road, Dongri and Bhen...
# 2     C                            Pydhonie and Bhuleshwar
# 3     D  Grant Road, Walkeshwar, Malabar Hill, Breach C...
# 4     E  Byculla, Madanpura, Agripada, Nagpada, Dockyar...
# 5    FN                Matunga, Sion, Wadala, Hindu Colony
# 6    FS                                              Parel
# 7    GN                           Dharavi, Mahim and Dadar
# 8    GS                               Worli and Prabhadevi
# 9    HE          Bandra East, Khar East and Santacruz East
# 10   HW             Bandra West, Khar West, Santacruz West
# 11   KE  Andheri East, Jogeshwari East, and Vile Parle ...
# 12   KW  Andheri West, Jogeshwari West, and Vile Parle ...
# 13    L           Sakinaka, Chandivali, Asalpha, and Kurla
# 14   ME  Mankhurd, Anushakti Nagar, Deonar, Cheetah Cam...
# ...

# %%
Final_covid_data_df = pd.merge(mumbai_ward_details,covid_data_df,on='Ward')
Final_covid_data_df
# Out:
#    Ward                              Areas under this Ward  Discharged  \
# 0     A                 Churchgate, Colaba, and Navy Nagar        7924
# 1     B  Masjid Bunder, Mohd. Ali Road, Dongri and Bhen...        2245
# 2     C                            Pydhonie and Bhuleshwar        4147
# 3     D  Grant Road, Walkeshwar, Malabar Hill, Breach C...       15064
# 4     E  Byculla, Madanpura, Agripada, Nagpada, Dockyar...       10555
# 5    FN                Matunga, Sion, Wadala, Hindu Colony       12969
# 6    FS                                              Parel       11285
# 7    GN                           Dharavi, Mahim and Dadar       14904
# 8    GS                               Worli and Prabhadevi       11009
# 9    HE          Bandra East, Khar East and Santacruz East       10668
# 10   HW             Bandra West, Khar West, Santacruz West       12284
# 11   KE  Andheri East, Jogeshwari East, and Vile Parle ...       19443
# ...

# %%
df = Final_covid_data_df[['Ward','Total Patients']]
df=df.sort_values("Total Patients",ascending=False)

df.set_index('Ward',inplace = True)

ax = df.plot(kind='bar', figsize=(10, 6), rot=0)

ax.set_ylabel('Number of Total COVID Patients')
ax.set_xlabel('Ward')
ax.set_title('Neighbourhoods in Mumbai with the number of Covid patients')

for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 14,
               )

plt.show()

# %%
df = Final_covid_data_df[['Ward','Deaths']]
df=df.sort_values("Deaths",ascending=False)

df.set_index('Ward',inplace = True)

ax = df.plot(kind='bar', figsize=(10, 6), rot=0)

ax.set_ylabel('Number of deaths COVID Patients')
ax.set_xlabel('Ward')
ax.set_title('Neighbourhoods in Mumbai with the number deaths of Covid patients')

for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 14,
               )

plt.show()

# %%
df = Final_covid_data_df[['Ward','Discharged']]
df=df.sort_values("Discharged",ascending=False)

df.set_index('Ward',inplace = True)

ax = df.plot(kind='bar', figsize=(10, 6), rot=0)

ax.set_ylabel('Number of Discharged COVID Patients')
ax.set_xlabel('Ward')
ax.set_title('Neighbourhoods in Mumbai with the number Discharged of Covid patients')

for p in ax.patches:
    ax.annotate(np.round(p.get_height(),decimals=2), 
                (p.get_x()+p.get_width()/2., p.get_height()), 
                ha='center', 
                va='center', 
                xytext=(0, 10), 
                textcoords='offset points',
                fontsize = 14,
               )

plt.show()
